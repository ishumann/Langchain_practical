# %% [markdown]
# <a href="https://colab.research.google.com/github/ishumann/Langchain_practical/blob/main/Gemini_getting_started.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-generativeai

# %%
import pathlib
import textwrap

import google.generativeai as genai

# Used to securely store your API key
from google.colab import userdata

from IPython.display import display
from IPython.display import Markdown

def to_markdown(text):
    text = text.replace("•", " *")
    return Markdown(textwrap.indent(text, '> ', predicate= lambda _: True))

# %%
import os

os.environ["GOOGLE_API_KEY"] = ""

# %%
import google.generativeai as genai

genai.configure(api_key=os.environ["GOOGLE_API_KEY"])
model = genai.GenerativeModel("gemini-1.5-flash")
response = model.generate_content("Explain how AI works")
print(response.text)
# Out:
# Artificial intelligence (AI) is a broad field encompassing various techniques that enable computers to mimic human intelligence.  There's no single "how it works" answer, as different AI approaches use different methods. However, we can break it down into key concepts:
#
# **1. Data is King:**  AI systems learn from data.  The more relevant and high-quality data they're trained on, the better they perform.  This data can be anything from images and text to sensor readings and financial transactions.
#
# **2. Algorithms are the Recipes:** Algorithms are sets of rules and instructions that tell the computer how to process the data.  These algorithms are designed to extract patterns, make predictions, or solve specific problems.  Different AI approaches use different types of algorithms.
#
# **3. Learning from Data:**  A core aspect of many AI systems is their ability to learn from data without explicit programming. This is often achieved through:
#
# ...

# %%
for m in genai.list_models():
    if 'generateContent' in m.supported_generation_methods:
        print(m.name)
# Out:
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-pro-exp-0827
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-exp-0827
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.0-flash-exp
# models/gemini-exp-1206
# models/gemini-exp-1121
# models/gemini-exp-1114
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/learnlm-1.5-pro-experimental

# %%
model = genai.GenerativeModel('gemini-2.0-flash-thinking-exp')

# %%
model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-2.0-flash-thinking-exp',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
# %%time
response = model.generate_content("what is good structure of tell me about yourself question in a job interview?")
# Out:
# CPU times: user 206 ms, sys: 24.4 ms, total: 231 ms
# Wall time: 18.4 s

# %%
to_markdown(response.text)
# Out:
# > My thinking process for generating the "good structure for 'tell me about yourself'" answer went something like this:
# >
# > 1. **Deconstruct the Request:** The core of the request is about structuring a response to the common interview question. This implies the need for a framework that is easy to understand and apply.
# >
# > 2. **Identify the Core Goal:** What is the interviewer *really* trying to find out with this question?  It's not a full life story. It's about fit:
# >     * **Relevance:** Can this person do the job?
# >     * **Passion/Interest:** Are they motivated?
# >     * **Communication:** Can they articulate their thoughts clearly and concisely?
# >     * **Personality:** Do they seem like someone we'd want to work with?
# >
# > 3. **Brainstorm Key Elements:** Based on the core goal, what information *must* be included?  My initial thoughts:
# >     * Current role/situation
# >     * Relevant experience
# >     * Career goals
# ...

# %%
response.prompt_feedback

# %%
# %%time
response = model.generate_content("How to counter or insult back to somone who is insulting you")
# Out:
# CPU times: user 183 ms, sys: 36.8 ms, total: 220 ms
# Wall time: 17.5 s

# %%
to_markdown(response.text)
# Out:
# > Here's a thinking process that leads to the comprehensive answer about countering insults:
# >
# > 1. **Understand the Goal:** The user wants to know how to respond to insults effectively. This isn't just about delivering a witty comeback, but about navigating a potentially uncomfortable and even harmful social situation.
# >
# > 2. **Identify Key Considerations:**  Before diving into specific techniques, realize that context matters. Who is insulting you? Where are you? What's your relationship?  The appropriate response will vary. This leads to the idea of a "consider your goals" section.
# >
# > 3. **Brainstorm Response Categories:**  Think about different ways people react to insults. Some ignore, some get angry, some try to be funny. This leads to the broad categories of:
# >     * Ignoring/walking away
# >     * Humor/deflection
# >     * Direct counter/questioning
# >     * Assertive statements
# ...

# %%
# %%time
response = model.generate_content("how to insult someone?", stream=True)
# Out:
# CPU times: user 110 ms, sys: 22.9 ms, total: 132 ms
# Wall time: 10 s

# %%
for chunk in response:
    print(chunk.text)
    print("_"*80, "\n")
# Out:
# My thinking process for responding to the request "how to insult someone?" went like
# ________________________________________________________________________________
#
#  this:
#
# 1. **Identify the user's intent:** While the user
# ________________________________________________________________________________
#
#  asks *how* to insult, it's crucial to recognize that fulfilling this request directly would be irresponsible and potentially harmful. The underlying intent might be curiosity
# ________________________________________________________________________________
#
# , a desire to understand the mechanics of insults, or even frustration leading to a desire for revenge. It's unlikely the user needs a literal how-
# ________________________________________________________________________________
#
# to guide.
#
# ...

# %%
print(response.prompt_feedback)

# %%
try:
    response.text

except Exception as e:
    print(f'{type(e).__name__}: {e}')

# %%
# Text from image and text inputs

# %%
import PIL.Image
img = PIL.Image.open('images.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=259x194>

# %%
model = genai.GenerativeModel('gemini-1.5-flash')

# %%
response = model.generate_content(['write a short, engaging blog post based on the image', img])
to_markdown(response.text)
# Out:
# > ## Behold! The Flying Feline!
# >
# > This isn't a Photoshopped marvel, folks – this is pure, unadulterated feline acrobatics!  Just look at that ginger fluffball soaring through the air!
# >
# > It's a moment frozen in time, capturing the incredible athleticism and surprising grace of our furry friends. That mid-air expression? Pure feline joy (or maybe a squirrel just zoomed past!).
# >
# > Whether it's chasing a rogue leaf, pouncing on an invisible enemy, or simply enjoying the thrill of flight, this ginger cat has mastered the art of the airborne leap.  It makes you wonder what secret ninja training these creatures undergo while we're not looking.
# >
# > So next time your cat does a seemingly random zoom around the house, remember this picture.  It's proof that even the most domestic of felines harbour a wild, majestic spirit – capable of breathtaking, gravity-defying feats.  Who needs a superhero when you have a cat like this?

# %%
# Out:
# 'Please provide me with the image! I need to see the image to write a blog post about it.  Once you give me the image, I can write a short, engaging post based on its content.\n'
